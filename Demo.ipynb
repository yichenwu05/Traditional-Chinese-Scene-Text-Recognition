# %%
# It may take some time to import ...
from module.demo import Demo
# Out:
# /workspace/research/maskrcnn/str_submit/module/demo.py:28: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   device_conf = yaml.load(rf)
# Loaded pretrained weights for efficientnet-b1

# %%
# Demo(filename)

# %%
for i in range(11):
    image, image_bb, res = Demo('demo_img_{}'.format(str(i+1)))
    print('\n========================================================\n')
# Out:
# 康是美
# ...
#
# 永豐金證券
# ...
#
# 巧味逢甲越南法國麵包
# ...
#
# 皇家時尚舘
# ...
#
# 行人專用時相
# ...
#
# 門前隱味
# ...
#
# 手搓粉圓小農茶飲牧場鮮奶
# ...
#
# 松本鮮奶茶
# ...
#
# 三商巧福
# ...
#
# 詹益光建築師事務所
# ...
#
# 樂仔餃子
# ...
